# %%
'''
Association rule learning is a machine learning technique used for discovering interesting 
patterns or relationships within large datasets. It is primarily applied in market basket
analysis, recommendation systems, and other domains where identifying associations between 
items or events is valuable. Two popular algorithms for association rule learning are Apriori
and Eclat.
'''
# Out:
# '\nAssociation rule learning is a machine learning technique used for discovering interesting \npatterns or relationships within large datasets. It is primarily applied in market basket\nanalysis, recommendation systems, and other domains where identifying associations between \nitems or events is valuable. Two popular algorithms for association rule learning are Apriori\nand Eclat.\n'

# %%
''' Apriori Algorithm:

Idea:
The Apriori algorithm is based on the "apriori principle," which states that
if an itemset is frequent, then all of its subsets must also be frequent. 
In other words, if a set of items is commonly found together in transactions, 
individual items within that set are likely to be found together as well.
    
Workflow:
Start with individual items and identify their frequency (support) in the dataset.
Generate candidate itemsets of length 2 by joining frequent itemsets of length 1.
Calculate the support for these candidate itemsets.
Prune itemsets that do not meet the minimum support threshold.
Repeat steps 2-4 for itemsets of increasing length until no more
frequent itemsets can be generated.

Uses:
Apriori is commonly used in market basket analysis to discover purchasing patterns.
For example, it can help identify which products are frequently bought together
in a retail store, allowing businesses to optimize product placement, promotions, 
and recommendations.'''
# Out:
# ' Apriori Algorithm:\n\nIdea:\nThe Apriori algorithm is based on the "apriori principle," which states that\nif an itemset is frequent, then all of its subsets must also be frequent. \nIn other words, if a set of items is commonly found together in transactions, \nindividual items within that set are likely to be found together as well.\n    \nWorkflow:\nStart with individual items and identify their frequency (support) in the dataset.\nGenerate candidate itemsets of length 2 by joining frequent itemsets of length 1.\nCalculate the support for these candidate itemsets.\nPrune itemsets that do not meet the minimum support threshold.\nRepeat steps 2-4 for itemsets of increasing length until no more\nfrequent itemsets can be generated.\n\nUses:\nApriori is commonly used in market basket analysis to discover purchasing patterns.\nFor example, it can help identify which products are frequently bought together\nin a retail store, allowing businesses to optimize product placement, promotion
# ...

# %%
# APRIORI

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import mall dataset with pandas
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header=None)

# %%
#import dataset as a list of list
transaction = []
for i in range (0,7501):
    transaction.append([str(dataset.values[i,j]) for j in range(0,20)])

# %%
pip install apyori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#training a priori on dataset
from apyori import apriori
rules = apriori(transaction, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_lenght = 2)

# %%
# Visualizing results
myResults = [list(x) for x in rules]

# Display the results
for result in myResults:
    print("Rule:", result[0])
    print("Support:", result[1])
    print("Confidence:", result[2][0][2])
    print("Lift:", result[2][0][3])
    print("------------------------")
# Out:
# Rule: frozenset({'chicken', 'light cream'})
# Support: 0.004532728969470737
# Confidence: 0.29059829059829057
# Lift: 4.84395061728395
# ------------------------
# Rule: frozenset({'mushroom cream sauce', 'escalope'})
# Support: 0.005732568990801226
# Confidence: 0.3006993006993007
# Lift: 3.790832696715049
# ------------------------
# Rule: frozenset({'escalope', 'pasta'})
# Support: 0.005865884548726837
# Confidence: 0.3728813559322034
# Lift: 4.700811850163794
# ------------------------
# Rule: frozenset({'honey', 'fromage blanc'})
# Support: 0.003332888948140248
# Confidence: 0.2450980392156863
# Lift: 5.164270764485569
# ------------------------
# Rule: frozenset({'ground beef', 'herb & pepper'})
# Support: 0.015997866951073192
# Confidence: 0.3234501347708895
# Lift: 3.2919938411349285
# ------------------------
# Rule: frozenset({'ground beef', 'tomato sauce'})
# Support: 0.005332622317024397
# Confidence: 0.3773584905660377
# Lift: 3.840659481324083
# ...
